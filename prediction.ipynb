# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L   0   1
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W   5   0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W   5   0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W   1   0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D   0   0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# 1    2022  Manchester City
# 2    2022  Manchester City
# 3    2022  Manchester City
# 4    2022  Manchester City
# 6    2022  Manchester City
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1520, 27)

# %%
# 2 seasons * 20 squads * 38 matches

2 * 20 * 38
# Out:
# 1520

# %%
# Missing Liverpool 2021-2022
matches["team"].value_counts()
# Out:
# Liverpool                   76
# Everton                     76
# Leicester City              76
# West Ham United             76
# Newcastle United            76
# Aston Villa                 76
# Wolverhampton Wanderers     76
# Southampton                 76
# Brighton and Hove Albion    76
# Tottenham Hotspur           76
# Crystal Palace              76
# Chelsea                     76
# Arsenal                     76
# Leeds United                76
# Manchester United           76
# Manchester City             76
# Burnley                     76
# Norwich City                38
# West Bromwich Albion        38
# Sheffield United            38
# Fulham                      38
# Brentford                   38
# Watford                     38
# Name: team, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 1   2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W   4   3
# 2   2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away      W   2   0
# 4   2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home      W   3   1
# 6   2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L   2   7
# 7   2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D   2   2
# ..         ...    ...             ...           ...  ...   ...    ...  ..  ..
# 55  2022-04-30  12:30  Premier League  Matchweek 35  Sat  Away      W   1   0
# 57  2022-05-07  19:45  Premier League  Matchweek 36  Sat  Home      D   1   1
# 58  2022-05-10  20:00  Premier League  Matchweek 33  Tue  Away      W   2   1
# 60  2022-05-17  19:45  Premier League  Matchweek 37  Tue  Away      W   2   1
# 61  2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W   3   1
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1    Leeds United  ...  Match Report    NaN  20.0   4.0  17.0  0.0  2.0   2.0
# 2         Chelsea  ...  Match Report    NaN  17.0   5.0  17.7  1.0  0.0   0.0
# 4         Arsenal  ...  Match Report    NaN  21.0   9.0  16.8  0.0  0.0   0.0
# 6     Aston Villa  ...  Match Report    NaN  14.0   8.0  15.8  1.0  0.0   0.0
# 7         Everton  ...  Match Report    NaN  22.0   8.0  15.0  1.0  0.0   0.0
# ..            ...  ...           ...    ...   ...   ...   ...  ...  ...   ...
# 55  Newcastle Utd  ...  Match Report    NaN  24.0  11.0  17.4  2.0  0.0   0.0
# 57      Tottenham  ...  Match Report    NaN  22.0   3.0  18.6  0.0  0.0   0.0
# 58    Aston Villa  ...  Match Report    NaN  17.0   5.0  15.4  2.0  0.0   0.0
# 60    Southampton  ...  Match Report    NaN  24.0   5.0  17.5  0.0  0.0   0.0
# 61         Wolves  ...  Match Report    NaN  29.0   7.0  15.2  0.0  0.0   0.0
#
#     season       team
# 1     2021  Liverpool
# 2     2021  Liverpool
# 4     2021  Liverpool
# 6     2021  Liverpool
# 7     2021  Liverpool
# ..     ...        ...
# 55    2022  Liverpool
# 57    2022  Liverpool
# 58    2022  Liverpool
# 60    2022  Liverpool
# 61    2022  Liverpool
#
# [76 rows x 27 columns]

# %%
matches["round"].value_counts()
# Out:
# Matchweek 8     40
# Matchweek 11    40
# Matchweek 14    40
# Matchweek 38    40
# Matchweek 13    40
# Matchweek 19    40
# Matchweek 10    40
# Matchweek 30    40
# Matchweek 28    40
# Matchweek 21    40
# Matchweek 7     40
# Matchweek 4     40
# Matchweek 29    40
# Matchweek 15    40
# Matchweek 2     40
# Matchweek 35    40
# Matchweek 36    40
# Matchweek 23    40
# Matchweek 20    40
# Matchweek 9     40
# Matchweek 18    40
# Matchweek 22    40
# Matchweek 3     40
# Matchweek 5     40
# Matchweek 12    40
# Matchweek 25    40
# Matchweek 37    40
# Matchweek 17    40
# Matchweek 24    40
# Matchweek 33    40
# Matchweek 27    40
# Matchweek 34    40
# Matchweek 6     40
# Matchweek 1     40
# Matchweek 31    40
# Matchweek 16    40
# Matchweek 32    40
# Matchweek 26    40
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L   0   1
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W   5   0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W   5   0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W   1   0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D   0   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L   0   4
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L   0   2
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W   1   0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L   0   1
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W   1   0
#
#           opponent  ...  notes    sh   sot  dist   fk   pk pkatt season  \
# 1        Tottenham  ...    NaN  18.0   4.0  16.9  1.0  0.0   0.0   2022
# 2     Norwich City  ...    NaN  16.0   4.0  17.3  1.0  0.0   0.0   2022
# 3          Arsenal  ...    NaN  25.0  10.0  14.3  0.0  0.0   0.0   2022
# 4   Leicester City  ...    NaN  25.0   8.0  14.0  0.0  0.0   0.0   2022
# 6      Southampton  ...    NaN  16.0   1.0  15.7  1.0  0.0   0.0   2022
# ..             ...  ...    ...   ...   ...   ...  ...  ...   ...    ...
# 38       Tottenham  ...    NaN   8.0   1.0  17.4  0.0  0.0   0.0   2021
# 39  Crystal Palace  ...    NaN   7.0   0.0  11.4  1.0  0.0   0.0   2021
# 40         Everton  ...    NaN  10.0   3.0  17.0  0.0  0.0   0.0   2021
# 41   Newcastle Utd  ...    NaN  11.0   1.0  16.0  1.0  0.0   0.0   2021
# 42         Burnley  ...    NaN  12.0   3.0  17.0  0.0  0.0   0.0   2021
#
#                 team  target
# 1    Manchester City       0
# 2    Manchester City       1
# 3    Manchester City       1
# 4    Manchester City       1
# 6    Manchester City       0
# ..               ...     ...
# 38  Sheffield United       0
# 39  Sheffield United       0
# 40  Sheffield United       1
# 41  Sheffield United       0
# 42  Sheffield United       1
#
# [1520 rows x 28 columns]

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L   0   1
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W   5   0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W   5   0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W   1   0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D   0   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L   0   4
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L   0   2
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W   1   0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L   0   1
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W   1   0
#
#           opponent  ...   fk   pk  pkatt  season              team target  \
# 1        Tottenham  ...  1.0  0.0    0.0    2022   Manchester City      0
# 2     Norwich City  ...  1.0  0.0    0.0    2022   Manchester City      1
# 3          Arsenal  ...  0.0  0.0    0.0    2022   Manchester City      1
# 4   Leicester City  ...  0.0  0.0    0.0    2022   Manchester City      1
# 6      Southampton  ...  1.0  0.0    0.0    2022   Manchester City      0
# ..             ...  ...  ...  ...    ...     ...               ...    ...
# 38       Tottenham  ...  0.0  0.0    0.0    2021  Sheffield United      0
# 39  Crystal Palace  ...  1.0  0.0    0.0    2021  Sheffield United      0
# 40         Everton  ...  0.0  0.0    0.0    2021  Sheffield United      1
# 41   Newcastle Utd  ...  1.0  0.0    0.0    2021  Sheffield United      0
# 42         Burnley  ...  0.0  0.0    0.0    2021  Sheffield United      1
#
#    venue_code opp_code  hour  day_code
# 1           0       18    16         6
# 2           1       15    15         5
# 3           1        0    12         5
# 4           0       10    15         5
# 6           1       17    15         5
# ..        ...      ...   ...       ...
# 38          0       18    19         6
# 39          1        6    15         5
# 40          0        7    19         6
# 41          0       14    18         2
# 42          1        4    16         6
#
# [1520 rows x 32 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2022-01-01']

# %%
test = matches[matches["date"] > '2022-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
error = accuracy_score(test["target"], preds)

# %%
error
# Out:
# 0.6056701030927835

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          186  47
# 1          106  49

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.5104166666666666

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3).mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group,cols,new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 4  2020-10-03  17:30  Premier League   Matchweek 4  Sat  Away      D   1   1
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W   1   0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D   1   1
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W   1   0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D   1   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 52 2022-04-30  17:30  Premier League  Matchweek 35  Sat  Away      W   4   0
# 54 2022-05-08  16:30  Premier League  Matchweek 36  Sun  Home      W   5   0
# 55 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Away      W   5   1
# 56 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D   2   2
# 57 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W   3   2
#
#          opponent  ...  hour  day_code  gf_rolling  ga_rolling sh_rolling  \
# 4    Leeds United  ...    17         5    2.000000    2.333333  17.333333
# 5         Arsenal  ...    17         5    1.333333    2.000000  17.333333
# 7        West Ham  ...    12         5    1.000000    0.666667  16.666667
# 9   Sheffield Utd  ...    12         5    1.000000    0.333333  14.333333
# 11      Liverpool  ...    16         6    1.000000    0.666667  12.000000
# ..            ...  ...   ...       ...         ...         ...        ...
# 52   Leeds United  ...    17         5    4.000000    0.333333  18.666667
# 54  Newcastle Utd  ...    16         6    4.666667    0.333333  20.000000
# 55         Wolves  ...    20         2    4.666667    0.333333  18.333333
# 56       West Ham  ...    14         6    4.000000    1.000000  22.000000
# 57    Aston Villa  ...    16         6    3.333333    1.666667  23.000000
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4     4.666667    18.900000   1.333333    0.333333       0.333333
# 5     3.666667    17.733333   0.666667    0.000000       0.000000
# 7     4.333333    18.233333   0.666667    0.000000       0.000000
# 9     6.666667    18.466667   1.000000    0.000000       0.000000
# 11    5.666667    19.366667   1.000000    0.000000       0.333333
# ..         ...          ...        ...         ...            ...
# 52    6.000000    16.333333   0.000000    0.333333       0.333333
# 54    7.333333    15.166667   0.333333    0.333333       0.333333
# 55    6.666667    14.933333   0.333333    0.000000       0.000000
# 56    7.000000    15.700000   1.000000    0.000000       0.333333
# 57    5.666667    15.200000   1.000000    0.000000       0.333333
#
# [74 rows x 40 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 4  2020-09-28  20:00  Premier League   Matchweek 3
#                         6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 37 2022-04-30  15:00  Premier League  Matchweek 35
#                         38 2022-05-07  15:00  Premier League  Matchweek 36
#                         39 2022-05-11  20:15  Premier League  Matchweek 33
#                         40 2022-05-15  14:00  Premier League  Matchweek 37
#                         41 2022-05-22  16:00  Premier League  Matchweek 38
#
#                             day venue result  gf  ga         opponent  ...  \
# team                                                                   ...
# Arsenal                 4   Mon  Away      L   1   3        Liverpool  ...
#                         6   Sun  Home      W   2   1    Sheffield Utd  ...
#                         7   Sat  Away      L   0   1  Manchester City  ...
#                         9   Sun  Home      L   0   1   Leicester City  ...
#                         11  Sun  Away      W   1   0   Manchester Utd  ...
# ...                         ...   ...    ...  ..  ..              ...  ...
# Wolverhampton Wanderers 37  Sat  Home      L   0   3         Brighton  ...
#                         38  Sat  Away      D   2   2          Chelsea  ...
#                         39  Wed  Home      L   1   5  Manchester City  ...
#                         40  Sun  Home      D   1   1     Norwich City  ...
#                         41  Sun  Away      L   1   3        Liverpool  ...
#
#                             hour  day_code  gf_rolling  ga_rolling sh_rolling  \
# team
# Arsenal                 4     20         0    2.000000    1.333333   7.666667
#                         6     14         6    1.666667    1.666667   5.333333
#                         7     17         5    1.000000    1.666667   7.000000
#                         9     19         6    0.666667    1.000000   9.666667
#                         11    16         6    0.333333    0.666667   9.666667
# ...                          ...       ...         ...         ...        ...
# Wolverhampton Wanderers 37    15         5    0.000000    1.666667   8.666667
#                         38    15         5    0.666667    2.000000  11.666667
#                         39    20         2    1.000000    3.333333  10.666667
#                         40    14         6    1.333333    2.666667  12.666667
#                         41    16         6    1.000000    3.000000  10.333333
#
#                            sot_rolling dist_rolling fk_rolling  pk_rolling  \
# team
# Arsenal                 4     3.666667    14.733333   0.666667    0.000000
#                         6     3.666667    15.766667   0.000000    0.000000
#                         7     3.666667    16.733333   0.666667    0.000000
#                         9     4.000000    16.033333   1.000000    0.000000
#                         11    2.666667    18.033333   1.000000    0.333333
# ...                                ...          ...        ...         ...
# Wolverhampton Wanderers 37    2.333333    18.233333   0.333333    0.000000
#                         38    3.000000    17.133333   0.333333    0.000000
#                         39    2.666667    16.400000   0.333333    0.000000
#                         40    3.666667    17.033333   0.666667    0.000000
#                         41    4.000000    17.000000   0.666667    0.000000
#
#                             pkatt_rolling
# team
# Arsenal                 4        0.000000
#                         6        0.000000
#                         7        0.000000
#                         9        0.000000
#                         11       0.333333
# ...                                   ...
# Wolverhampton Wanderers 37       0.000000
#                         38       0.000000
#                         39       0.000000
#                         40       0.000000
#                         41       0.000000
#
# [1471 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 4  2020-09-28  20:00  Premier League   Matchweek 3  Mon  Away      L   1   3
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W   2   1
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L   0   1
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L   0   1
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W   1   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 37 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Home      L   0   3
# 38 2022-05-07  15:00  Premier League  Matchweek 36  Sat  Away      D   2   2
# 39 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Home      L   1   5
# 40 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Home      D   1   1
# 41 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Away      L   1   3
#
#            opponent  ...  hour  day_code  gf_rolling  ga_rolling sh_rolling  \
# 4         Liverpool  ...    20         0    2.000000    1.333333   7.666667
# 6     Sheffield Utd  ...    14         6    1.666667    1.666667   5.333333
# 7   Manchester City  ...    17         5    1.000000    1.666667   7.000000
# 9    Leicester City  ...    19         6    0.666667    1.000000   9.666667
# 11   Manchester Utd  ...    16         6    0.333333    0.666667   9.666667
# ..              ...  ...   ...       ...         ...         ...        ...
# 37         Brighton  ...    15         5    0.000000    1.666667   8.666667
# 38          Chelsea  ...    15         5    0.666667    2.000000  11.666667
# 39  Manchester City  ...    20         2    1.000000    3.333333  10.666667
# 40     Norwich City  ...    14         6    1.333333    2.666667  12.666667
# 41        Liverpool  ...    16         6    1.000000    3.000000  10.333333
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4     3.666667    14.733333   0.666667    0.000000       0.000000
# 6     3.666667    15.766667   0.000000    0.000000       0.000000
# 7     3.666667    16.733333   0.666667    0.000000       0.000000
# 9     4.000000    16.033333   1.000000    0.000000       0.000000
# 11    2.666667    18.033333   1.000000    0.333333       0.333333
# ..         ...          ...        ...         ...            ...
# 37    2.333333    18.233333   0.333333    0.000000       0.000000
# 38    3.000000    17.133333   0.333333    0.000000       0.000000
# 39    2.666667    16.400000   0.333333    0.000000       0.000000
# 40    3.666667    17.033333   0.666667    0.000000       0.000000
# 41    4.000000    17.000000   0.666667    0.000000       0.000000
#
# [1471 rows x 40 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result  gf  \
# 0    2020-09-28  20:00  Premier League   Matchweek 3  Mon  Away      L   1
# 1    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W   2
# 2    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L   0
# 3    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L   0
# 4    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W   1
# ...         ...    ...             ...           ...  ...   ...    ...  ..
# 1466 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Home      L   0
# 1467 2022-05-07  15:00  Premier League  Matchweek 36  Sat  Away      D   2
# 1468 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Home      L   1
# 1469 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Home      D   1
# 1470 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Away      L   1
#
#       ga         opponent  ...  hour  day_code  gf_rolling  ga_rolling  \
# 0      3        Liverpool  ...    20         0    2.000000    1.333333
# 1      1    Sheffield Utd  ...    14         6    1.666667    1.666667
# 2      1  Manchester City  ...    17         5    1.000000    1.666667
# 3      1   Leicester City  ...    19         6    0.666667    1.000000
# 4      0   Manchester Utd  ...    16         6    0.333333    0.666667
# ...   ..              ...  ...   ...       ...         ...         ...
# 1466   3         Brighton  ...    15         5    0.000000    1.666667
# 1467   2          Chelsea  ...    15         5    0.666667    2.000000
# 1468   5  Manchester City  ...    20         2    1.000000    3.333333
# 1469   1     Norwich City  ...    14         6    1.333333    2.666667
# 1470   3        Liverpool  ...    16         6    1.000000    3.000000
#
#      sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0      7.666667    3.666667    14.733333   0.666667    0.000000       0.000000
# 1      5.333333    3.666667    15.766667   0.000000    0.000000       0.000000
# 2      7.000000    3.666667    16.733333   0.666667    0.000000       0.000000
# 3      9.666667    4.000000    16.033333   1.000000    0.000000       0.000000
# 4      9.666667    2.666667    18.033333   1.000000    0.333333       0.333333
# ...         ...         ...          ...        ...         ...            ...
# 1466   8.666667    2.333333    18.233333   0.333333    0.000000       0.000000
# 1467  11.666667    3.000000    17.133333   0.333333    0.000000       0.000000
# 1468  10.666667    2.666667    16.400000   0.333333    0.000000       0.000000
# 1469  12.666667    3.666667    17.033333   0.666667    0.000000       0.000000
# 1470  10.333333    4.000000    17.000000   0.666667    0.000000       0.000000
#
# [1471 rows x 40 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.7364341085271318

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted       date     team        opponent result
# 56       0          1 2022-01-23  Arsenal         Burnley      D
# 57       1          0 2022-02-10  Arsenal          Wolves      W
# 58       1          0 2022-02-19  Arsenal       Brentford      W
# 59       1          1 2022-02-24  Arsenal          Wolves      W
# 60       1          1 2022-03-06  Arsenal         Watford      W
# 61       1          1 2022-03-13  Arsenal  Leicester City      W
# 62       0          0 2022-03-16  Arsenal       Liverpool      L
# 63       1          0 2022-03-19  Arsenal     Aston Villa      W
# 64       0          0 2022-04-04  Arsenal  Crystal Palace      L
# 65       0          0 2022-04-09  Arsenal        Brighton      L

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton",
              "Manchester United": "Manchester Utd",
              "Newcastle United": "Newcastle Utd",
              "Tottenham Hotspur": "Tottenham",
              "West Ham United": "West Ham",
              "Wolverhampton Wanderers": "Wolves"} 

mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 56         0          1 2022-01-23                  Arsenal          Burnley
# 57         1          0 2022-02-10                  Arsenal           Wolves
# 58         1          0 2022-02-19                  Arsenal        Brentford
# 59         1          1 2022-02-24                  Arsenal           Wolves
# 60         1          1 2022-03-06                  Arsenal          Watford
# ...      ...        ...        ...                      ...              ...
# 1466       0          0 2022-04-30  Wolverhampton Wanderers         Brighton
# 1467       0          0 2022-05-07  Wolverhampton Wanderers          Chelsea
# 1468       0          0 2022-05-11  Wolverhampton Wanderers  Manchester City
# 1469       0          0 2022-05-15  Wolverhampton Wanderers     Norwich City
# 1470       0          0 2022-05-22  Wolverhampton Wanderers        Liverpool
#
#      result new_team
# 56        D  Arsenal
# 57        W  Arsenal
# 58        W  Arsenal
# 59        W  Arsenal
# 60        W  Arsenal
# ...     ...      ...
# 1466      L   Wolves
# 1467      D   Wolves
# 1468      L   Wolves
# 1469      D   Wolves
# 1470      L   Wolves
#
# [388 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           0            1 2022-01-23                  Arsenal
# 1           1            0 2022-02-10                  Arsenal
# 2           1            0 2022-02-19                  Arsenal
# 3           1            1 2022-02-24                  Arsenal
# 4           1            1 2022-03-06                  Arsenal
# ..        ...          ...        ...                      ...
# 383         0            0 2022-04-30  Wolverhampton Wanderers
# 384         0            0 2022-05-07  Wolverhampton Wanderers
# 385         0            0 2022-05-11  Wolverhampton Wanderers
# 386         0            0 2022-05-15  Wolverhampton Wanderers
# 387         0            0 2022-05-22  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0            Burnley        D    Arsenal         0            0
# 1             Wolves        W    Arsenal         0            1
# 2          Brentford        W    Arsenal         0            0
# 3             Wolves        W    Arsenal         0            1
# 4            Watford        W    Arsenal         0            0
# ..               ...      ...        ...       ...          ...
# 383         Brighton        L     Wolves         1            0
# 384          Chelsea        D     Wolves         0            0
# 385  Manchester City        L     Wolves         1            1
# 386     Norwich City        D     Wolves         0            0
# 387        Liverpool        L     Wolves         1            1
#
#                        team_y opponent_y result_y       new_team_y
# 0                     Burnley    Arsenal        D          Burnley
# 1     Wolverhampton Wanderers    Arsenal        L           Wolves
# 2                   Brentford    Arsenal        L        Brentford
# 3     Wolverhampton Wanderers    Arsenal        L           Wolves
# 4                     Watford    Arsenal        L          Watford
# ..                        ...        ...      ...              ...
# 383  Brighton and Hove Albion     Wolves        W         Brighton
# 384                   Chelsea     Wolves        D          Chelsea
# 385           Manchester City     Wolves        W  Manchester City
# 386              Norwich City     Wolves        D     Norwich City
# 387                 Liverpool     Wolves        W        Liverpool
#
# [388 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    92
# 0    25
# Name: actual_x, dtype: int64

# %%
# Accuracy
92/117
# Out:
# 0.7863247863247863
